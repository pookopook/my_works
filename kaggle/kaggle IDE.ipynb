# %% [markdown]
# # kaggle ide
#  - kaggle ide with jupyternotebook
# ``` shell
# !pip install kaggle
# ```
#  - get gpi
#    ![image.png](attachment:image.png)
#     - download kaggle.json
#  - paste file at
#    ```
#    C:\Users\*username*\.kaggle
#    ```
#  - get Titanic sample data
#  ``` python
#  !kaggle competitions download -c titanic
#
#  data = titanic
#  import zipfile
#  with zipfile.ZipFile(f'./{data}.zip', r') as zip:
#     zip.extractall(f'./{data}/dataset')
#  ```

# %% [markdown]
# - 샘플데이터
#     * Titanic - Machine Learning from Disaster
#     * https://www.kaggle.com/competitions/titanic/data

# %%
# !kaggle competitions download -c titanic
data = 'titanic'

import zipfile
with zipfile.ZipFile(f'./{data}.zip', 'r') as zip:
   zip.extractall(f'./{data}/dataset')

import os
os.remove(f'./{data}.zip')
